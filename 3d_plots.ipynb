# %%
# %matplotlib widget

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

import numpy as np

# %%
from nvmeutils import *

# %%
ax = plt.figure().add_subplot(projection='3d')

x = [99.15240678, 184.83885, 295.2819, 305.328083333, 305.1295, 306.000233333, 305.790576271, 307.539016667,]
y = [9.780193342, 10.516885481, 13.248170129, 25.899857876, 52.145129739000005, 104.298515055, 209.027050463, 416.015932793]
z = [1, 2, 4, 8, 16, 32, 64, 128]
ax.scatter(x, y, z, marker='o')
  
x = [83.104516667, 164.648372881, 269.21311864399996, 307.27105, 307.470610169, 299.852949153, 295.83449152500003, 295.26234999999997]
y = [11.740589909, 11.904466346, 14.634598691999999, 25.821928439, 51.843203988, 106.583327278, 216.256737271, 433.534301755]
z = [1, 2, 4, 8, 16, 32, 64, 128]
ax.scatter(x, y, z, marker='o')    
    
ax.set_xlabel('Througput')
ax.set_ylabel('Latency')
ax.set_zlabel('Queue depth')

plt.show()

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "spdk", "WUS4B7696DSP303_________________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.iops_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (KIOPS)')

plt.show()

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "spdk", "WUS4B7696DSP303_________________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append((dat.iops_mean * bs) / 1024 / 1024)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)
ax.set_zlim(0,1500)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (mb/s)')

plt.show()

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "io_uring", "WUS4B7696DSP303_________________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.iops_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (KIOPS)')

plt.show()

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "io_uring", "WUS4B7696DSP303_________________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append((dat.iops_mean * bs) / 1024 / 1024)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)
ax.set_zlim(0,1500)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (mb/s)')

plt.show()

# %%
bss = [4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "spdk", "WUS4B7696DSP303_________________________", 
                    "lbaf3", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.iops_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (6, 10))
y = np.reshape(Y, (6, 10))
z = np.reshape(Z, (6, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (KIOPS)')

plt.show()

# %%
bss = [4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "spdk", "WUS4B7696DSP303_________________________", 
                    "lbaf3", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append((dat.iops_mean * bs) / 1024 / 1024)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (6, 10))
y = np.reshape(Y, (6, 10))
z = np.reshape(Z, (6, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)
ax.set_zlim(0,1500)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (mb/s)')

plt.show()

# %%
bss = [4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "io_uring", "WUS4B7696DSP303_________________________", 
                    "lbaf3", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.iops_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (6, 10))
y = np.reshape(Y, (6, 10))
z = np.reshape(Z, (6, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (KIOPS)')

plt.show()

# %%
bss = [4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "io_uring", "WUS4B7696DSP303_________________________", 
                    "lbaf3", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append((dat.iops_mean * bs) / 1024 / 1024)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (6, 10))
y = np.reshape(Y, (6, 10))
z = np.reshape(Z, (6, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)
ax.set_zlim(0,1500)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (mb/s)')

plt.show()

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "spdk", "WUS4B7696DSP303_________________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.lat_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Lat (micros)')

plt.show()

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "io_uring", "WUS4B7696DSP303_________________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.lat_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Lat (micros)')

plt.show()

# %%
# %pip install ipympl
# %jupyter labextension install @jupyter-widgets/jupyterlab-manager jupyter-matplotlib

# %%
bs = 4096

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones")
ax.grid(True)

# %%
bs = 4096 * 2

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones")
ax.grid(True)

# %%
bs = 4096 * 2

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones")
ax.grid(True)

# %%
bs = 4096

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones (lbaf0, bs=4096)")
ax.grid(True)

# %%
bs = 4096 * 2

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones (lbaf0, bs=8192)")
ax.grid(True)

# %%
bs = 131072

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones (lbaf0, bs=131072)")
ax.grid(True)

# %%
bs = 512

fig, ax = plt.subplots()
x = []
y = []
y_err = []
xrange = [1,2,4]

for czones in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", czones, 1, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

# plt.plot(
#     xrange,
#     y,
#     linewidth=3,
#     label='concurrent zones',
#     color="cyan",
# )  

plt.bar(
    [x -0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Concurrent zones",
    color="cyan",
)

x = []
y = []
y_err = []
xrange = [1,2,4]

for qd in xrange:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    y.append(dat.iops_mean / 1000)
    y_err.append(dat.iops_stddev / 1000)

plt.bar(
    [x + 0.125 for x in range(len(xrange))],
    y,
    yerr=y_err,
    width=0.25,
    label="Append",
    color="Magenta",
)  
        
plt.legend()

plt.xticks([x for x in range(len(xrange))], [str(x) for x in xrange])

plt.xlabel("Concurrency")
plt.ylabel("Througput (KIOPS)")
plt.title("ZNS KIOPS append and concurrent zones (lbaf0, bs=512)")
ax.grid(True)

# %%
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
qdss = [1,2,4,8,16,32,64,128,256,512]

X=[]
Y=[]
Z=[]

i = j = 0
for bs in bss:
    j = 0
    for qd in qdss:
        dat = parse_fio_file(
                DataPath(
                    "io_uring", "Samsung_SSD_980_PRO_2TB_________________", 
                    "lbaf0", "write", 1, qd, bs
                )
            )
        X.append(i)
        Y.append(j)
        Z.append(dat.iops_mean / 1000)
        j = j + 1
    i = i + 1
    
x = np.reshape(X, (9, 10))
y = np.reshape(Y, (9, 10))
z = np.reshape(Z, (9, 10))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.xaxis.set_ticks(list(range(len(bss))), bss)  
ax.yaxis.set_ticks(list(range(len(qdss))), qdss)  

ax.plot_surface(x, y, z)

ax.set_xlabel('Block size')
ax.set_ylabel('Queue dept')
ax.set_zlabel('Throughput (KIOPS)')

plt.show()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append versus write performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32,64]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] == 1:
                plt.text((kiops[i] - 25) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 15) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            elif qdss[i] > 8:
                plt.text((kiops[i] - 35) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i] - 25) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 15) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
                
qdss = [1,2,4,8,16]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="appends",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] >= 8:
                plt.text((kiops[i] + 3) * (1.01), (lats[i]+5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i] + 3) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] + 3) * (1.01), (lats[i]-10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] + 3) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 300)
plt.ylim(0, 250)
plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append versus write performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 8:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 15) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text(kiops[i] * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 160)
plt.ylim(0, 250)
plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance")
ax.grid(True)

qdss = [1,2,4,8,16,32]

    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text(kiops[i] * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 160)
plt.ylim(0, 250)
# plt.legend()

# %%
qd = 4
bss = [4096, 8192, 16384, 32768, 65536, 131072]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, bs
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Request size")
plt.title("Append througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 160)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#EE6677")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB", "128KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 4
bss = [4096, 8192, 16384, 32768, 65536, 131072]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, bs
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Request size")
plt.title("Append througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 160)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#EE6677")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB", "128KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 32
bss = [4096, 8192, 16384, 32768, 65536, 131072]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, 32, bs
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Request size")
plt.title("Write througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 300)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#4477AA")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB", "128KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
# ... MARKER 1 ...
qd = 32
bss = [4096, 8192, 16384, 32768, 65536, 131072]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3nvme", "write", 1, 32, bs
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Request size")
plt.title("Write througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 300)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#4477AA")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB", "128KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 32
bss = [4096, 8192, 16384, 32768, 65536, 131072]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, 32, bs
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Request size")
plt.title("Write througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 320)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#228833")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB", "128KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 4
bss = [4096, 8192, 16384, 32768, 65536]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, bs
            )
        )
    kiops.append(dat.lat_mean / 1000)
    kiopse.append(dat.lat_stdef / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Latency (micros)")
plt.ylabel("Request size")
plt.title("Append latency")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 450)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#EE6677")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 32
bss = [4096, 8192, 16384, 32768, 65536]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, bs
            )
        )
    kiops.append(dat.lat_mean / 1000)
    kiopse.append(dat.lat_stdef / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Latency (micros)")
plt.ylabel("Request size")
plt.title("Write latency")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 2500)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#4477AA")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
# ... MARKER 1 ...
qd = 32
bss = [4096, 8192, 16384, 32768, 65536]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3nvme", "write", 1, qd, bs
            )
        )
    kiops.append(dat.lat_mean / 1000)
    kiopse.append(dat.lat_stdef / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Latency (micros)")
plt.ylabel("Request size")
plt.title("Write latency")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 2500)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#4477AA")
ax.set_yticks(range(len(bss)), labels=["4KiB", "8KiB", "16KiB", "32KiB", "64KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 4
conc = [1,2,4]
# https://personal.sron.nl/~pault/

fig, ax = plt.subplots()
plt.xlabel("Latency (micros)")
plt.ylabel("Level of concurrency")
plt.title("Append latency")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 80)

kiops = []
kiopse = []
for c in conc:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", c, 1, 4096<<1
            )
        )
    kiops.append(dat.lat_mean / 1000)
    kiopse.append(dat.lat_stdef / 1000)

ax.barh([(x*0.6) - 0.125 for x in range(len(conc))], kiops, xerr=kiopse, align='center', color="#AA3377", height=0.25,
       label='Appends to concurrent zones')

kiops = []
kiopse = []
for c in conc:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, c, 4096<<1
            )
        )
    kiops.append(dat.lat_mean / 1000)
    kiopse.append(dat.lat_stdef / 1000)
    
    
ax.barh([(x*0.6) + 0.125 for x in range(len(conc))], kiops, xerr=kiopse, align='center', color="#EE6677", height=0.25,
       label='Appends with higher QD')
    
ax.set_yticks([x * 0.6 for x in range(len(conc))], labels=["1", "2", "4"])
ax.invert_yaxis()  # labels read top-to-bottom

plt.legend()

# %%
qd = 4
conc = [1,2,4]
# https://personal.sron.nl/~pault/

fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Level of concurrency")
plt.title("Append througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 160)

kiops = []
kiopse = []
for c in conc:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", c, 1, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

ax.barh([(x*0.6) - 0.125 for x in range(len(conc))], kiops, xerr=kiopse, align='center', color="#AA3377", 
        height=0.25, label='Appends to concurrent zones')

kiops = []
kiopse = []
for c in conc:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, c, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)
    
    
ax.barh([(x*0.6) + 0.125 for x in range(len(conc))], kiops, xerr=kiopse, align='center', color="#EE6677", 
        height=0.25, label='Appends with higher QD')
    
ax.set_yticks([x*0.6 for x in range(len(conc))], labels=["1", "2", "4"])
ax.invert_yaxis()  # labels read top-to-bottom

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance (request size=32KiB)")
ax.grid(True)

qdss = [1,2,4,8]
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 32768
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 32768
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
                
                
plt.xlim(0, 160)
plt.ylim(0, 250)

plt.legend()

# %%
# ... MARKER 2 ...
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Write performance for NVMe SSDs (request size=16KiB)")
ax.grid(True)

qdss = [1,2,4,8]
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf0", "write", 1, qd, 16384
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="WD NVMe",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

qdss = [1,2,4,8,16]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "Samsung_SSD_980_PRO_2TB_________________", 
            "lbaf0", "write", 1, qd, 16384
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="Samsung NVMe",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
                
                
plt.xlim(0, 200)
plt.ylim(0, 250)

plt.legend()

# %%
# ... MARKER 2 ...
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Write performance for NVMe SSDs (request size=32KiB)")
ax.grid(True)

qdss = [1,2,4,8]
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf0", "write", 1, qd, 32768
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="WD NVMe",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "Samsung_SSD_980_PRO_2TB_________________", 
            "lbaf0", "write", 1, qd, 32768
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="Samsung NVMe",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
                
                
plt.xlim(0, 160)
plt.ylim(0, 250)

plt.legend()

# %%
# ... MARKER 2 ...
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Write performance for NVMe SSDs (request size=64KiB)")
ax.grid(True)

qdss = [1,2,4]
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf0", "write", 1, qd, 65536
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="WD NVMe",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "Samsung_SSD_980_PRO_2TB_________________", 
            "lbaf0", "write", 1, qd, 65536
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="Samsung NVMe",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
                
                
plt.xlim(0, 160)
plt.ylim(0, 250)

plt.legend()

# %%
# ... MARKER 2 ...
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Write performance for NVMe SSDs (request size=128KiB)")
ax.grid(True)

qdss = [1,2]
bss = [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf0", "write", 1, qd, 131072
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="WD NVMe",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

qdss = [1,2,4]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "Samsung_SSD_980_PRO_2TB_________________", 
            "lbaf0", "write", 1, qd, 131072
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="Samsung NVMe",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
                
                
plt.xlim(0, 160)
plt.ylim(0, 250)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance (request size=512 bytes)")
ax.grid(True)

qdss = [1,2,4,8]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, 512
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")

lats = [25,50,100,200]
for i in range(len(kiops)): 
    if qdss[i] < 4:
        plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
    else:
        plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "writemq", 1, qd, 512
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
                
                
plt.xlim(0, 160)
plt.ylim(0, 250)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance (request size=2KiBs)")
ax.grid(True)

qdss = [1,2,4,8]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, 2048
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")

lats = [25,50,100,200]
for i in range(len(kiops)): 
    if qdss[i] < 4:
        plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
    else:
        plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "writemq", 1, qd, 2048
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
                
                
plt.xlim(0, 160)
plt.ylim(0, 250)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, 8192
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 512 bytes pages",
    color="#AA3377",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#AA3377")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 8192
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 4KiB pages",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
                
                
plt.xlim(0, 160)
plt.ylim(0, 60)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Write performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "writemq", 1, qd, 8192
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 512 bytes pages",
    color="#66CCEE",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#66CCEE")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 8192
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 4KiB pages",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
                
                
plt.xlim(0, 160)
plt.ylim(0, 60)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 512 bytes pages",
    color="#AA3377",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#AA3377")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 4KiB pages",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
                
                
plt.xlim(0, 160)
plt.ylim(0, 100)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Write performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32,64]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "writemq", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 512 bytes pages",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i]-25) * (1.01), (lats[i]+3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]-15) * (1.01), kiops[i]],[(lats[i]+1) *
                     (1.01),lats[i]], color='grey')
            elif qdss[i] == 8:
                plt.text((kiops[i]-25) * (1.01), (lats[i]+10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]-15) * (1.01), kiops[i]],[(lats[i]+9) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 30) * (1.01), (lats[i]+3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] -20) * (1.01), kiops[i]],[(lats[i]+1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 4KiB pages",
    color="#66CCEE",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#66CCEE")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-8) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-7) *
                     (1.01),lats[i]], color='grey')
            elif qdss[i] > 16:
                plt.text((kiops[i] -30) * (1.01), (lats[i]+8) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]-30) * (1.01), kiops[i]],[(lats[i]+7) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-8) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-7) *
                     (1.01),lats[i]], color='grey')

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#66CCEE")
                
                
plt.xlim(0, 300)
plt.ylim(0, 300)

plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("Append performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8]
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, qd, 4096 << 2
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 512 bytes pages",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096 << 2
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="lba format 4KiB pages",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i]+5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] +5) * (1.01), (lats[i]-3) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]+5) * (1.01), kiops[i]],[(lats[i]-1) *
                     (1.01),lats[i]], color='grey')

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
                
                
plt.xlim(0, 160)
plt.ylim(0, 100)

plt.legend()

# %%
qd = 32
bss = [4096, 8192, 16384, 32768, 65536, 131072]

kiops = []
kiopse = []
for operation in ["write", "append"]:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", operation, 1, 1, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("SPDK operation")
plt.title("Operation throughput (QD=1, request size=8KiB)")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 200)

ax.barh([0.125,0.5], kiops, xerr=kiopse, align='center', color=["#AA3377", "#EE6677"], height=0.25)
ax.set_yticks([0.125,0.5], labels=["write", "append"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 1
bss = [512, 1024, 2048]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, 32, bs
            )
        )
    kiops.append(dat.iops_mean / 1000)
    kiopse.append(dat.iops_stddev / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("Request size")
plt.title("Append througput")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 50)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#EE6677")
ax.set_yticks(range(len(bss)), labels=["512", "1KiB", "2KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
qd = 1
bss = [512, 1024, 2048]

kiops = []
kiopse = []
for bs in bss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf0", "append", 1, 32, bs
            )
        )
    kiops.append(dat.lat_mean / 1000)
    kiopse.append(dat.lat_stdef / 1000)

    
fig, ax = plt.subplots()
plt.xlabel("Latency (micros)")
plt.ylabel("Request size")
plt.title("Append Latency")
ax.xaxis.grid() # horizontal lines
plt.xlim(0, 1000)

ax.barh(range(len(bss)), kiops, xerr=kiopse, align='center', color="#EE6677")
ax.set_yticks(range(len(bss)), labels=["512", "1KiB", "2KiB"])
ax.invert_yaxis()  # labels read top-to-bottom

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS append versus NVMe write performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text(kiops[i] * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 8:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 15) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 160)
plt.ylim(0, 250)
plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS versus NVMe write performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text(kiops[i] * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 8:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 15) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 160)
plt.ylim(0, 250)
plt.legend()

# %%
#... MARKER 1 ...#

fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS versus NVMe write performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text(kiops[i] * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3nvme", "write", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS (NVMe namespace) writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 8:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 15) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 160)
plt.ylim(0, 250)
plt.legend()

# %%
#... MARKER 1 ...#

fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS versus NVMe write performance (request size=8KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 10) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-10) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text(kiops[i] * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3nvme", "write", 1, qd, 4096<<1
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS (NVMe namespace) writes",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 8:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 15) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 160)
plt.ylim(0, 250)
plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS append versus NVMe write performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i]-30) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]-30)  * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
qdss = [1,2,4,8,16]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "append", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS append",
    color="#EE6677",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#EE6677")
            if qdss[i] < 4:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 25) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 15) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 320)
plt.ylim(0, 150)
plt.legend()

# %%
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS versus NVMe write performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32,64]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-5) *
                     (1.01),lats[i]], color='grey')
            elif qdss[i] >= 32:
                pass
            else:
                plt.text((kiops[i]-30) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]-30)  * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
qdss = [1,2,4,8,16,32,64]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3", "writemq", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS write",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 25) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 15) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 320)
plt.ylim(0, 300)
plt.legend()

# %%
# ... Marker 1 ...
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS versus NVMe write performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32,64]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-5) *
                     (1.01),lats[i]], color='grey')
            elif qdss[i] >= 32:
                pass
            else:
                plt.text((kiops[i]-30) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]-30)  * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
qdss = [1,2,4,8,16,32]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "io_uring", "WZS4C8T1TDSP303_________________________", 
            "lbaf3nvme", "write", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS write",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 25) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 15) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 320)
plt.ylim(0, 300)
plt.legend()

# %%
# ... Marker 1 ...
fig, ax = plt.subplots()
plt.xlabel("Througput (KIOPS)")
plt.ylabel("latency (micros)")
plt.title("ZNS versus NVMe write performance (request size=4KiB)")
ax.grid(True)

qdss = [1,2,4,8,16,32,64]

kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WUS4B7696DSP303_________________________", 
            "lbaf3", "write", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)
    
plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="NVMe writes",
    color="#228833",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#228833")
            if qdss[i] < 4:
                plt.text(kiops[i] * (1.01), (lats[i] - 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)                
                plt.plot([(kiops[i]) * (1.01), kiops[i]],[(lats[i]-5) *
                     (1.01),lats[i]], color='grey')
            elif qdss[i] >= 32:
                pass
            else:
                plt.text((kiops[i]-30) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i]-30)  * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
    
qdss = [1,2,4,8,16,32]
kiops = []
lats = []
for qd in qdss:
    dat = parse_fio_file(
        DataPath(
            "spdk", "WZS4C8T1TDSP303_________________________", 
            "lbaf3nvme", "write", 1, qd, 4096
            )
        )
    kiops.append(dat.iops_mean / 1000)
    lats.append(dat.lat_mean / 1000)

plt.plot(
    kiops,
    lats,
    linewidth=3,
    label="ZNS write",
    color="#4477AA",
)

for i in range(len(kiops)):
            plt.plot(kiops[i], lats[i], "o", color="#4477AA")
            if qdss[i] < 4:
                plt.text((kiops[i] - 10) * (1.01), (lats[i] + 5) *
                         (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 5) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')
            else:
                plt.text((kiops[i] - 25) * (1.01), (lats[i] + 5) *
                     (1.01), s='qd='+str(qdss[i]), fontsize=9)
                plt.plot([(kiops[i] - 15) * (1.01), kiops[i]],[(lats[i]+5) *
                     (1.01),lats[i]], color='grey')

plt.xlim(0, 320)
plt.ylim(0, 300)
plt.legend()
